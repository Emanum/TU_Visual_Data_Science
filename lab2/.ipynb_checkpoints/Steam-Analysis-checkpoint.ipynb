# %% [markdown]
# # Lab Part 1 - Steam Analysis

# %%
# standard library imports
import itertools
import re
import math

# third-party imports
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# customisations
pd.set_option("max_columns", 100)
plt.style.use('default')
plt.rcdefaults()
# sns.set() # default seaborn style

# %%
df = pd.read_csv(
    filepath_or_buffer = 'datasets/steam/steam.csv',sep=',', decimal = ".", )
list(df.columns)
# Out:
# ['appid',
#  'name',
#  'release_date',
#  'english',
#  'developer',
#  'publisher',
#  'platforms',
#  'required_age',
#  'categories',
#  'genres',
#  'steamspy_tags',
#  'achievements',
#  'positive_ratings',
#  'negative_ratings',
#  'average_playtime',
#  'median_playtime',
#  'owners',
#  'price']

# %%
df.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %%
def get_unique(series):
    """Get unique values from a Pandas series containing semi-colon delimited strings."""
    return set(list(itertools.chain(*series.apply(lambda x: [c for c in x.split(';')]))))

def get_unique_list(series):
    return set(list(itertools.chain(*series.apply(lambda x: [c for c in x]))))

# %%
get_unique(df['categories'])
get_unique(df['genres'])
get_unique(df['platforms'])
get_unique(df['steamspy_tags'])
# Out:
# {'1980s',
#  "1990's",
#  '2.5D',
#  '2D',
#  '2D Fighter',
#  '360 Video',
#  '3D',
#  '3D Platformer',
#  '3D Vision',
#  '4 Player Local',
#  '4X',
#  '6DOF',
#  'Abstract',
#  'Action',
#  'Action RPG',
#  'Action-Adventure',
#  'Adventure',
#  'Agriculture',
#  'Aliens',
#  'Alternate History',
#  'America',
#  'Animation & Modeling',
#  'Anime',
#  'Arcade',
#  'Arena Shooter',
#  'Assassin',
#  'Atmospheric',
#  'Audio Production',
#  'BMX',
#  'Base-Building',
#  'Baseball',
#  'Basketball',
#  'Batman',
#  'Battle Royale',
#  "Beat 'em up",
#  'Beautiful',
#  'Benchmark',
#  'Bikes',
#  'Blood',
#  'Board Game',
#  'Bowling',
#  'Building',
#  'Bullet Hell',
#  'Bullet Time',
#  'CRPG',
#  'Capitalism',
#  'Card Game',
#  'Cartoon',
#  'Cartoony',
#  'Casual',
#  'Cats',
#  'Character Action Game',
#  'Character Customization',
#  'Chess',
#  'Choices Matter',
#  'Choose Your Own Adventure',
#  'Cinematic',
#  'City Builder',
#  'Class-Based',
#  'Classic',
#  'Clicker',
#  'Co-op',
#  'Cold War',
#  'Colorful',
#  'Comedy',
#  'Comic Book',
#  'Competitive',
#  'Controller',
#  'Conversation',
#  'Crafting',
#  'Crime',
#  'Cult Classic',
#  'Cute',
#  'Cyberpunk',
#  'Cycling',
#  'Dark',
#  'Dark Fantasy',
#  'Dark Humor',
#  'Dating Sim',
#  'Demons',
#  'Design & Illustration',
#  'Destruction',
#  'Detective',
#  'Difficult',
#  'Dinosaurs',
#  'Diplomacy',
#  'Documentary',
#  'Dog',
#  'Dragons',
#  'Drama',
#  'Driving',
#  'Dungeon Crawler',
#  'Dungeons & Dragons',
#  'Dystopian ',
#  'Early Access',
#  'Economy',
#  'Education',
#  'Epic',
#  'Experimental',
#  'Exploration',
#  'FMV',
#  'FPS',
#  'Faith',
#  'Family Friendly',
#  'Fantasy',
#  'Fast-Paced',
#  'Female Protagonist',
#  'Fighting',
#  'First-Person',
#  'Fishing',
#  'Flight',
#  'Football',
#  'Free to Play',
#  'Funny',
#  'Futuristic',
#  'Gambling',
#  'Game Development',
#  'GameMaker',
#  'Games Workshop',
#  'God Game',
#  'Golf',
#  'Gore',
#  'Gothic',
#  'Grand Strategy',
#  'Great Soundtrack',
#  'Grid-Based Movement',
#  'Gun Customization',
#  'Hack and Slash',
#  'Hacking',
#  'Hand-drawn',
#  'Heist',
#  'Hex Grid',
#  'Hidden Object',
#  'Historical',
#  'Hockey',
#  'Horror',
#  'Horses',
#  'Hunting',
#  'Illuminati',
#  'Indie',
#  'Intentionally Awkward Controls',
#  'Interactive Fiction',
#  'Inventory Management',
#  'Investigation',
#  'Isometric',
#  'JRPG',
#  'Kickstarter',
#  'LEGO',
#  'Lara Croft',
#  'Lemmings',
#  'Level Editor',
#  'Linear',
#  'Local Co-Op',
#  'Local Multiplayer',
#  'Logic',
#  'Loot',
#  'Lovecraftian',
#  'MMORPG',
#  'MOBA',
#  'Magic',
#  'Management',
#  'Mars',
#  'Martial Arts',
#  'Massively Multiplayer',
#  'Masterpiece',
#  'Match 3',
#  'Mature',
#  'Mechs',
#  'Medieval',
#  'Memes',
#  'Metroidvania',
#  'Military',
#  'Mini Golf',
#  'Minimalist',
#  'Mining',
#  'Mod',
#  'Moddable',
#  'Motocross',
#  'Motorbike',
#  'Mouse only',
#  'Movie',
#  'Multiplayer',
#  'Multiple Endings',
#  'Music',
#  'Music-Based Procedural Generation',
#  'Mystery',
#  'Mystery Dungeon',
#  'Mythology',
#  'NSFW',
#  'Narration',
#  'Naval',
#  'Ninja',
#  'Noir',
#  'Nonlinear',
#  'Nudity',
#  'Offroad',
#  'Old School',
#  'On-Rails Shooter',
#  'Online Co-Op',
#  'Open World',
#  'Otome',
#  'Parkour',
#  'Parody ',
#  'Party-Based RPG',
#  'Perma Death',
#  'Philisophical',
#  'Photo Editing',
#  'Physics',
#  'Pinball',
#  'Pirates',
#  'Pixel Graphics',
#  'Platformer',
#  'Point & Click',
#  'Political',
#  'Politics',
#  'Pool',
#  'Post-apocalyptic',
#  'Procedural Generation',
#  'Programming',
#  'Psychedelic',
#  'Psychological',
#  'Psychological Horror',
#  'Puzzle',
#  'Puzzle-Platformer',
#  'PvP',
#  'Quick-Time Events',
#  'RPG',
#  'RPGMaker',
#  'RTS',
#  'Racing',
#  'Real Time Tactics',
#  'Real-Time',
#  'Real-Time with Pause',
#  'Realistic',
#  'Relaxing',
#  'Remake',
#  'Replay Value',
#  'Resource Management',
#  'Retro',
#  'Rhythm',
#  'Robots',
#  'Rogue-like',
#  'Rogue-lite',
#  'Romance',
#  'Rome',
#  'Runner',
#  'Sailing',
#  'Sandbox',
#  'Satire',
#  'Sci-fi',
#  'Science',
#  'Score Attack',
#  'Sexual Content',
#  "Shoot 'Em Up",
#  'Shooter',
#  'Short',
#  'Side Scroller',
#  'Simulation',
#  'Singleplayer',
#  'Skateboarding',
#  'Skating',
#  'Sniper',
#  'Snow',
#  'Snowboarding',
#  'Soccer',
#  'Software',
#  'Software Training',
#  'Sokoban',
#  'Souls-like',
#  'Space',
#  'Space Sim',
#  'Spectacle fighter',
#  'Spelling',
#  'Split Screen',
#  'Sports',
#  'Star Wars',
#  'Stealth',
#  'Steampunk',
#  'Story Rich',
#  'Strategy',
#  'Strategy RPG',
#  'Stylized',
#  'Submarine',
#  'Superhero',
#  'Supernatural',
#  'Surreal',
#  'Survival',
#  'Survival Horror',
#  'Swordplay',
#  'Tactical',
#  'Tactical RPG',
#  'Tanks',
#  'Team-Based',
#  'Tennis',
#  'Text-Based',
#  'Third Person',
#  'Third-Person Shooter',
#  'Thriller',
#  'Time Attack',
#  'Time Management',
#  'Time Manipulation',
#  'Time Travel',
#  'Top-Down',
#  'Top-Down Shooter',
#  'Touch-Friendly',
#  'Tower Defense',
#  'Trading',
#  'Trading Card Game',
#  'Trains',
#  'Turn-Based',
#  'Turn-Based Combat',
#  'Turn-Based Strategy',
#  'Turn-Based Tactics',
#  'Twin Stick Shooter',
#  'Typing',
#  'Underwater',
#  'Utilities',
#  'VR',
#  'VR Only',
#  'Vampire',
#  'Video Production',
#  'Villain Protagonist',
#  'Violent',
#  'Visual Novel',
#  'Voice Control',
#  'Voxel',
#  'Walking Simulator',
#  'War',
#  'Wargame',
#  'Warhammer 40K',
#  'Web Publishing',
#  'Werewolves',
#  'Western',
#  'Word Game',
#  'World War I',
#  'World War II',
#  'Wrestling',
#  'Zombies',
#  'e-sports'}

# %%
def processPlattform(df):
    plat_cols = get_unique(df['platforms'])
    
    # create a new column for each platform, with 1s indicating membership and 0s for non-members
    for col in sorted(plat_cols):
        plat_name = re.sub(r'[\s\-\/]', '_', col.lower())
        plat_name = re.sub(r'[()]', '', plat_name)
        
        df[plat_name] = df['platforms'].apply(lambda x: 1 if col in x.split(';') else 0)

# %%
def process_cat_gen_tag(df):
    """Process categories, genres, steamspy_tags and platform columns."""
    # get all unique plattform names
    plat_cols = get_unique(df['platforms'])
    
    # create a new column for each platform, with 1s indicating membership and 0s for non-members
    for col in sorted(plat_cols):
        plat_name = re.sub(r'[\s\-\/]', '_', col.lower())
        plat_name = re.sub(r'[()]', '', plat_name)
        
        df[plat_name] = df['platforms'].apply(lambda x: 1 if col in x.split(';') else 0)
    
    # get all unique category names
    cat_cols = get_unique(df['categories'])
    
    # create a new column for each category, with 1s indicating membership and 0s for non-members
    for col in sorted(cat_cols):
        col_name = re.sub(r'[\s\-\/]', '_', col.lower())
        col_name = re.sub(r'[()]', '', col_name)
        
        df[col_name] = df['categories'].apply(lambda x: 1 if col in x.split(';') else 0)
        
    # repeat for genre column names (get_unique used to find unique genre names, 
    # not necessary but useful if keeping all of them)
    gen_cols = get_unique(df['genres'])  
    gen_col_names = []
    
    # create new columns for each genre with 1s for games of that genre
    for col in sorted(gen_cols):
        col_name = col.lower().replace('&', 'and').replace(' ', '_')
        gen_col_names.append(col_name)
        
        df[col_name] = df['genres'].apply(lambda x: 1 if col in x.split(';') else 0)
        # alternate method using np.where:
        # df[col_name] = np.where(df['genres'].str.contains(col), 1, 0)
    
    # not using steamspy tags for now, as mostly overlap with genres
    # here's one way we could deal with them:
    tag_cols = get_unique(df['steamspy_tags'])
    df['top_tag'] = df['steamspy_tags'].apply(lambda x: x.split(';')[0])
    
    # remove redundant columns and return dataframe (keeping genres column for reference)
    df = df.drop(['categories', 'steamspy_tags','platforms'], axis=1)
    
    return df

# %%
def handleMultipleItemColumn(df,column,sep):
    df[column] = df[column].apply(lambda x: x.split(sep))

# %%
def calc_rating(row):
    """Calculate rating score based on SteamDB method."""
    import math

    pos = row['positive_ratings']
    neg = row['negative_ratings']

    total_reviews = pos + neg
    average = pos / total_reviews
    
    # pulls score towards 50, pulls more strongly for games with few reviews
    score = average - (average*0.5) * 2**(-math.log10(total_reviews + 1))

    return score * 100

# %%
def pre_process():
    """Preprocess Steam dataset for exploratory analysis."""
    df = pd.read_csv(filepath_or_buffer = 'datasets/steam/steam.csv',sep=',', decimal = ".")
    
    # keep lower and higher bound of owners column, as integer
    df['owners_low_bound'] = df['owners'].str.split('-').apply(lambda x: x[0]).astype(int)
    df['owners_high_bound'] = df['owners'].str.split('-').apply(lambda x: x[1]).astype(int)
    del df['owners']
    
    # calculate rating, as well as simple ratio for comparison
    df['total_ratings'] = df['positive_ratings'] + df['negative_ratings']
    df['rating_ratio'] = df['positive_ratings'] / df['total_ratings']
    df['rating'] = df.apply(calc_rating, axis=1)
    
    # convert release_date to datetime type and create separate column for release_year
    df['release_date'] = df['release_date'].astype('datetime64[ns]')
    df['release_year'] = df['release_date'].apply(lambda x: x.year)
    
    # process genres, categories and steamspy_tag columns
    #df = process_cat_gen_tag(df)
    #df['platforms_all'] = df['platforms'].apply(lambda x: mapPlatform(x))
    processPlattform(df)
    handleMultipleItemColumn(df,'platforms',';')
    handleMultipleItemColumn(df,'categories',';')
    df['top_tag'] = df['steamspy_tags'].apply(lambda x: x.split(';')[0])
    handleMultipleItemColumn(df,'steamspy_tags',';')
    handleMultipleItemColumn(df,'developer',';')
    handleMultipleItemColumn(df,'publisher',';')
    handleMultipleItemColumn(df,'genres',';')
    
    # Create a column to split free vs paid games
    df['type'] = 'Free'
    df.loc[df['price'] > 0, 'type'] = 'Paid'
    
    # Add Value total playtime
    df['total_playtime'] = df.apply (lambda row: row.average_playtime*row.owners_low_bound, axis=1)

    # Add Value total playtime
    df['estimated_revenue'] = df.apply (lambda row: row.price*row.owners_low_bound, axis=1)

    return df

# %%
processedDF = pre_process()
pDF = processedDF

# %%
processedDF.head()
# Out:
#    appid                       name release_date  english           developer  \
# 0     10             Counter-Strike   2000-11-01        1             [Valve]
# 1     20      Team Fortress Classic   1999-04-01        1             [Valve]
# 2     30              Day of Defeat   2003-05-01        1             [Valve]
# 3     40         Deathmatch Classic   2001-06-01        1             [Valve]
# 4     50  Half-Life: Opposing Force   1999-11-01        1  [Gearbox Software]
#
#   publisher              platforms  required_age  \
# 0   [Valve]  [windows, mac, linux]             0
# 1   [Valve]  [windows, mac, linux]             0
# 2   [Valve]  [windows, mac, linux]             0
# 3   [Valve]  [windows, mac, linux]             0
# 4   [Valve]  [windows, mac, linux]             0
#
#                                           categories    genres  \
# 0  [Multi-player, Online Multi-Player, Local Mult...  [Action]
# 1  [Multi-player, Online Multi-Player, Local Mult...  [Action]
# 2           [Multi-player, Valve Anti-Cheat enabled]  [Action]
# 3  [Multi-player, Online Multi-Player, Local Mult...  [Action]
# 4  [Single-player, Multi-player, Valve Anti-Cheat...  [Action]
#
#                       steamspy_tags  achievements  positive_ratings  \
# 0        [Action, FPS, Multiplayer]             0            124534
# 1        [Action, FPS, Multiplayer]             0              3318
# 2  [FPS, World War II, Multiplayer]             0              3416
# 3        [Action, FPS, Multiplayer]             0              1273
# 4             [FPS, Action, Sci-fi]             0              5250
#
#    negative_ratings  average_playtime  median_playtime  price  \
# 0              3339             17612              317   7.19
# 1               633               277               62   3.99
# 2               398               187               34   3.99
# 3               267               258              184   3.99
# 4               288               624              415   3.99
#
#    owners_low_bound  owners_high_bound  total_ratings  rating_ratio  \
# 0          10000000           20000000         127873      0.973888
# 1           5000000           10000000           3951      0.839787
# 2           5000000           10000000           3814      0.895648
# 3           5000000           10000000           1540      0.826623
# 4           5000000           10000000           5538      0.947996
#
#       rating  release_year  linux  mac  windows top_tag  type  total_playtime  \
# 0  95.975678          2000      1    1        1  Action  Paid    176120000000
# 1  80.508259          1999      1    1        1  Action  Paid      1385000000
# 2  85.823915          2003      1    1        1     FPS  Paid       935000000
# 3  78.126542          2001      1    1        1  Action  Paid      1290000000
# 4  91.260480          1999      1    1        1     FPS  Paid      3120000000
#
#    estimated_revenue
# 0         71900000.0
# 1         19950000.0
# 2         19950000.0
# 3         19950000.0
# 4         19950000.0

# %%
list(processedDF.columns) 
processedDF.shape
# Out:
# (27075, 30)

# %%
processedDF.describe()
# Out:
#               appid       english  required_age  achievements  \
# count  2.707500e+04  27075.000000  27075.000000  27075.000000
# mean   5.962035e+05      0.981127      0.354903     45.248864
# std    2.508942e+05      0.136081      2.406044    352.670281
# min    1.000000e+01      0.000000      0.000000      0.000000
# 25%    4.012300e+05      1.000000      0.000000      0.000000
# 50%    5.990700e+05      1.000000      0.000000      7.000000
# 75%    7.987600e+05      1.000000      0.000000     23.000000
# max    1.069460e+06      1.000000     18.000000   9821.000000
#
#        positive_ratings  negative_ratings  average_playtime  median_playtime  \
# count      2.707500e+04      27075.000000      27075.000000      27075.00000
# mean       1.000559e+03        211.027147        149.804949        146.05603
# std        1.898872e+04       4284.938531       1827.038141       2353.88008
# min        0.000000e+00          0.000000          0.000000          0.00000
# 25%        6.000000e+00          2.000000          0.000000          0.00000
# 50%        2.400000e+01          9.000000          0.000000          0.00000
# 75%        1.260000e+02         42.000000          0.000000          0.00000
# max        2.644404e+06     487076.000000     190625.000000     190625.00000
#
#               price  owners_low_bound  owners_high_bound  total_ratings  \
# count  27075.000000      2.707500e+04       2.707500e+04   2.707500e+04
# mean       6.078193      8.012669e+04       1.880543e+05   1.211586e+03
# std        7.874922      8.708977e+05       1.786801e+06   2.242909e+04
# min        0.000000      0.000000e+00       2.000000e+04   1.000000e+00
# 25%        1.690000      0.000000e+00       2.000000e+04   1.000000e+01
# 50%        3.990000      0.000000e+00       2.000000e+04   3.600000e+01
# 75%        7.190000      2.000000e+04       5.000000e+04   1.760000e+02
# max      421.990000      1.000000e+08       2.000000e+08   3.046717e+06
#
#        rating_ratio        rating  release_year         linux           mac  \
# count  27075.000000  27075.000000  27075.000000  27075.000000  27075.000000
# mean       0.714478     58.830540   2016.498098      0.193352      0.297913
# std        0.233594     20.100043      2.156990      0.394934      0.457350
# min        0.000000      0.000000   1997.000000      0.000000      0.000000
# 25%        0.583333     47.136581   2016.000000      0.000000      0.000000
# 50%        0.760331     62.651461   2017.000000      0.000000      0.000000
# 75%        0.893905     73.483405   2018.000000      0.000000      1.000000
# max        1.000000     97.257760   2019.000000      1.000000      1.000000
#
#             windows  total_playtime  estimated_revenue
# count  27075.000000    2.707500e+04       2.707500e+04
# mean       0.999815    2.886696e+08       6.953147e+05
# std        0.013588    1.767700e+10       9.673244e+06
# min        0.000000    0.000000e+00       0.000000e+00
# 25%        1.000000    0.000000e+00       0.000000e+00
# 50%        1.000000    0.000000e+00       0.000000e+00
# 75%        1.000000    0.000000e+00       1.580000e+04
# max        1.000000    2.394400e+12       1.349500e+09

# %%
# Filter Games mit wenig Usernb

# %%
pDF.boxplot(column=['owners_low_bound','owners_high_bound'], return_type='axes',showfliers=False)
# Out:
# <AxesSubplot:>

# %%
#indexNames = pDF[ pDF['owners_low_bound'] < 5000 ].index
# Delete these row indexes from dataFrame
#pDF.drop(indexNames , inplace=True)
#len(indexNames)

# %%
pDF.shape
# Out:
# (27075, 30)

# %%
#Unterschied playtime vs price
xCol = 'median_playtime'
yCol = 'owners_low_bound' 


color =  np.array(['red','blue'])
plt.scatter(marker='.',x=pDF[xCol],y=pDF[yCol])
plt.xlabel(xCol)
plt.ylabel(yCol)
plt.title('Combination '+xCol+','+yCol +' ')
# Out:
# Text(0.5, 1.0, 'Combination median_playtime,owners_low_bound ')

# %%
processedDF.sort_values(by='median_playtime',ascending=False)
# Out:
#          appid                                               name  \
# 9201    474030                        The Abbey of Crime Extensum
# 1478    219340                          The Banner Saga: Factions
# 6014    380140               The Secret of Tremendous Corporation
# 2023    252690                                    Fantasy Grounds
# 23409   892420                                              懒人修仙传
# ...        ...                                                ...
# 11913   553450                                      The Purge Day
# 11912   553440  R.A.T.S. (Regulatory Astro-Topographical Stabi...
# 11911   553430                Skill Master VR -- Learn Meditation
# 11910   553410                                     Pirate Defense
# 27074  1069460                                          Rune Lord
#
#       release_date  english  \
# 9201    2016-05-19        1
# 1478    2013-02-25        1
# 6014    2015-10-12        1
# 2023    2014-05-09        1
# 23409   2018-11-14        0
# ...            ...      ...
# 11913   2016-11-25        1
# 11912   2017-02-15        1
# 11911   2016-11-21        1
# 11910   2016-11-11        1
# 27074   2019-04-24        1
#
#                                                developer  \
# 9201                      [Manuel Pazos, Daniel Celemín]
# 1478                                             [Stoic]
# 6014   [Sebastian Krzyszkowiak, Konrad Burandt, Paweł...
# 2023                               [SmiteWorks USA, LLC]
# 23409                                            [托更的修罗]
# ...                                                  ...
# 11913                                  [Red Limb Studio]
# 11912                              [Mark Miller Studios]
# 11911                    [fletcher.richman, owockitalki]
# 11910                  [Rushil Reddy, Christiane Snyder]
# 27074                                 [Adept Studios GD]
#
#                             publisher              platforms  required_age  \
# 9201   [Manuel Pazos, Daniel Celemín]  [windows, mac, linux]             0
# 1478                    [Versus Evil]         [windows, mac]             0
# 6014                  [dosowisko.net]       [windows, linux]             0
# 2023            [SmiteWorks USA, LLC]         [windows, mac]             0
# 23409                         [托更的修罗]              [windows]             0
# ...                               ...                    ...           ...
# 11913              [Red Limb Studio ]              [windows]             0
# 11912                [I.E.D. Studios]              [windows]             0
# 11911            [Boulder VR Studios]              [windows]             0
# 11910                  [Rushil Reddy]              [windows]             0
# 27074          [Alawar Entertainment]         [windows, mac]             0
#
#                                               categories  \
# 9201                                     [Single-player]
# 1478          [Multi-player, Cross-Platform Multiplayer]
# 6014    [Single-player, Captions available, Steam Cloud]
# 2023   [Multi-player, Co-op, Cross-Platform Multiplayer]
# 23409                                    [Single-player]
# ...                                                  ...
# 11913  [Single-player, Steam Achievements, Full contr...
# 11912  [Single-player, Steam Achievements, Partial Co...
# 11911                [Single-player, Steam Achievements]
# 11910               [Single-player, Steam Trading Cards]
# 27074                       [Single-player, Steam Cloud]
#
#                                          genres  \
# 9201                  [Adventure, Free to Play]
# 1478       [Free to Play, Indie, RPG, Strategy]
# 6014   [Adventure, Casual, Free to Play, Indie]
# 2023                     [Indie, RPG, Strategy]
# 23409          [Casual, Indie, RPG, Simulation]
# ...                                         ...
# 11913                  [Violent, Action, Indie]
# 11912                           [Action, Indie]
# 11911                     [Indie, Early Access]
# 11910                                [Strategy]
# 27074                [Adventure, Casual, Indie]
#
#                           steamspy_tags  achievements  positive_ratings  \
# 9201   [Free to Play, Adventure, Retro]             0               146
# 1478      [Free to Play, Strategy, RPG]            42               569
# 6014   [Free to Play, Adventure, Indie]             0               218
# 2023          [RPG, Strategy, Software]             0               377
# 23409       [Simulation, Indie, Casual]             0               404
# ...                                 ...           ...               ...
# 11913          [Indie, Action, Violent]            14                22
# 11912                   [Action, Indie]             9                 9
# 11911     [Early Access, Indie, Casual]             9                 3
# 11910     [Strategy, VR, Tower Defense]             0                 5
# 27074        [Indie, Casual, Adventure]             0                 4
#
#        negative_ratings  average_playtime  median_playtime  price  \
# 9201                 22            190625           190625   0.00
# 1478                202             95245           190489   0.00
# 6014                 50             95242           190445   0.00
# 2023                100             43074            86148  29.99
# 23409               164             43632            71857   2.89
# ...                 ...               ...              ...    ...
# 11913                16                 0                0   1.99
# 11912                 2                 0                0   0.00
# 11911                 2                 0                0  10.99
# 11910                 5                 0                0   6.99
# 27074                 0                 0                0   5.19
#
#        owners_low_bound  owners_high_bound  total_ratings  rating_ratio  \
# 9201              50000             100000            168      0.869048
# 1478             200000             500000            771      0.738003
# 6014             100000             200000            268      0.813433
# 2023              20000              50000            477      0.790356
# 23409             20000              50000            568      0.711268
# ...                 ...                ...            ...           ...
# 11913                 0              20000             38      0.578947
# 11912                 0              20000             11      0.818182
# 11911                 0              20000              5      0.600000
# 11910                 0              20000             10      0.500000
# 27074                 0              20000              4      1.000000
#
#           rating  release_year  linux  mac  windows       top_tag  type  \
# 9201   77.628930          2016      1    1        1  Free to Play  Free
# 1478   68.814073          2013      0    1        1  Free to Play  Free
# 6014   73.794736          2015      1    0        1  Free to Play  Free
# 2023   72.866781          2014      0    1        1           RPG  Paid
# 23409  65.858932          2018      0    0        1    Simulation  Paid
# ...          ...           ...    ...  ...      ...           ...   ...
# 11913  48.286340          2016      0    0        1         Indie  Paid
# 11912  62.456017          2017      0    0        1        Action  Free
# 11911  42.506594          2016      0    0        1  Early Access  Paid
# 11910  37.853544          2016      0    0        1      Strategy  Paid
# 27074  69.199408          2019      0    1        1         Indie  Paid
#
#        total_playtime  estimated_revenue
# 9201       9531250000                0.0
# 1478      19049000000                0.0
# 6014       9524200000                0.0
# 2023        861480000           599800.0
# 23409       872640000            57800.0
# ...               ...                ...
# 11913               0                0.0
# 11912               0                0.0
# 11911               0                0.0
# 11910               0                0.0
# 27074               0                0.0
#
# [27075 rows x 30 columns]

# %%
processedDF['owners_low_bound'].median()
# Out:
# 0.0

# %% [markdown]
# ## Top played games
# Get the top x% of Games based on User

# %%
percent = 50
pDF.sort_values(by='owners_low_bound',ascending=False)
numberOfTopGames = math.ceil(len(pDF.index) * percent / 100 )
print("total number",len(pDF.index))
print("top",percent,"%",numberOfTopGames)
# Out:
# total number 27075
# top 50 % 13538

# %%
topPDF = pDF.sort_values(by='owners_low_bound',ascending=False).head(numberOfTopGames)

# %%
#topPDF

# %%
def scatterPlot(df,xCol,yCol,color):
    color =  np.array(['red','blue'])
    plt.scatter(marker='.',x=df[xCol],y=df[yCol])
    plt.xlabel(xCol)
    plt.ylabel(yCol)
    plt.title('Combination '+xCol+','+yCol +' ')

# %%
#scatterPlot(topPDF,'release_year','type','')

# %%
# Release per Year
df = pDF.copy()

years = []
lt_20k = []
gt_20k = []

for year in sorted(df['release_year'].unique()):
    if year < 2006 or year > 2018:
        # very few releases in data prior to 2006, and we're still in 2019 (at time of writing)
        # so ignore these years
        continue
    
    # subset dataframe by year
    year_df = df[df.release_year == year]
    
    # calculate total with less than 20,000 owners, and total with 20,000 or more
    total_lt_20k = year_df[year_df.type == "Free"].shape[0]
    total_gt_20k = year_df[year_df.type == "Paid"].shape[0]
    
    years.append(year)
    lt_20k.append(total_lt_20k)
    gt_20k.append(total_gt_20k)
    
owners_df = pd.DataFrame(zip(years, lt_20k, gt_20k), 
                         columns=['year', 'Free', 'Paid'])

ax = owners_df.plot(x='year', y=[1, 2], kind='bar', stacked=True, color=['tab:red', 'blue'])

ax.set_xlabel('')
ax.set_ylabel('Number of Releases')
ax.set_title('Number of releases by year, broken down by the type')
sns.despine()
plt.show()

# %%
#df = topPDF.copy()
#df['total_playtime'] = df.apply (lambda row: row.average_playtime*row.owners_low_bound, axis=1)
#topPDF.sort_values(by='total_playtime',ascending=False)

# %%
# Playtime ( sum(average_playtime*owners_lower_bound) ) per Year
df = pDF.copy()

#df['total_playtime'] = df.apply (lambda row: row.average_playtime*row.owners_low_bound, axis=1)

years = []
lt_20k = []
gt_20k = []

for year in sorted(df['release_year'].unique()):
    if year < 2006 or year > 2018:
        # very few releases in data prior to 2006, and we're still in 2019 (at time of writing)
        # so ignore these years
        continue
    
    # subset dataframe by year
    year_df = df[df.release_year == year]
    
    # calculate total with less than 20,000 owners, and total with 20,000 or more
    total_lt_20k = year_df[year_df.type == "Free"]['total_playtime'].sum()
    total_gt_20k = year_df[year_df.type == "Paid"]['total_playtime'].sum()
    
    years.append(year)
    lt_20k.append(total_lt_20k)
    gt_20k.append(total_gt_20k)
    
owners_df = pd.DataFrame(zip(years, lt_20k, gt_20k), 
                         columns=['year', 'Free', 'Paid'])

ax = owners_df.plot(x='year', y=[1, 2], kind='bar', stacked=True, color=['tab:red', 'blue'])

ax.set_xlabel('')
ax.set_ylabel('sum(average_playtime*owners_lower_bound)')
ax.set_title('total Playtime per release date')
sns.despine()
plt.show()

# %% [markdown]
# ### Aussage
#
# Es gibt ein paar Spiele die extrem populär sind und mehr spielzeit generieren als tausende andere spiele zusammen.

# %%
# Playtime ( sum(average_playtime*owners_lower_bound) ) per Year
df = pDF.copy()

#df['total_playtime'] = df.apply (lambda row: row.average_playtime*row.owners_low_bound, axis=1)

years = []
lt_20k = []
gt_20k = []

for year in sorted(df['release_year'].unique()):
    if year < 2006 or year > 2018:
        # very few releases in data prior to 2006, and we're still in 2019 (at time of writing)
        # so ignore these years
        continue
    
    # subset dataframe by year
    year_df = df[df.release_year == year]
    
    # calculate total with less than 20,000 owners, and total with 20,000 or more
    total_lt_20k = year_df[year_df.type == "Free"]['total_playtime'].sum()
    total_gt_20k = year_df[year_df.type == "Paid"]['total_playtime'].sum()
    
    years.append(year)
    lt_20k.append(total_lt_20k)
    gt_20k.append(total_gt_20k)
    
    
years = ['all Years']
gesamtlt = np.sum(lt_20k)
gesamtgt = np.sum(gt_20k)

gesamtGesamt = gesamtlt + gesamtgt

print("FREE",gesamtlt / gesamtGesamt)
print("PAID",gesamtgt / gesamtGesamt)


owners_df = pd.DataFrame(zip(years, [gesamtlt], [gesamtgt]), 
                         columns=['year', 'Free', 'Paid'])

ax = owners_df.plot(x='year', y=[1, 2], kind='bar', stacked=False, color=['tab:red', 'blue'])

ax.set_xlabel('')
ax.set_ylabel('sum(average_playtime*owners_lower_bound)')
ax.set_title('total Playtime combined')
sns.despine()
plt.show()
# Out:
# FREE 0.6140612525625283
# PAID 0.3859387474374717

# %%
pDF.sort_values(by='total_playtime',ascending=False).head(20)
# Out:
#         appid                              name release_date  english  \
# 22        570                            Dota 2   2013-07-09        1
# 12836  578080     PLAYERUNKNOWN'S BATTLEGROUNDS   2017-12-21        1
# 25        730  Counter-Strike: Global Offensive   2012-08-21        1
# 0          10                    Counter-Strike   2000-11-01        1
# 19        440                   Team Fortress 2   2007-10-10        1
# 121      4000                       Garry's Mod   2006-11-29        1
# 1634   230410                          Warframe   2013-03-25        1
# 2478   271590                Grand Theft Auto V   2015-04-13        1
# 1025    72850       The Elder Scrolls V: Skyrim   2011-11-10        1
# 4712   346110             ARK: Survival Evolved   2017-08-27        1
# 10        240            Counter-Strike: Source   2004-11-01        1
# 3362   304930                          Unturned   2017-07-07        1
# 1772   238960                     Path of Exile   2013-10-23        1
# 5390   363970                    Clicker Heroes   2015-05-13        1
# 2016   252490                              Rust   2018-02-08        1
# 1727   236390                       War Thunder   2013-08-15        1
# 1467   218620                          PAYDAY 2   2013-08-13        1
# 1127   107410                            Arma 3   2013-09-12        1
# 5235   359550   Tom Clancy's Rainbow Six® Siege   2015-12-01        1
# 12965  582010             MONSTER HUNTER: WORLD   2018-08-09        1
#
#                                                developer  \
# 22                                               [Valve]
# 12836                                 [PUBG Corporation]
# 25                    [Valve, Hidden Path Entertainment]
# 0                                                [Valve]
# 19                                               [Valve]
# 121                                  [Facepunch Studios]
# 1634                                  [Digital Extremes]
# 2478                                    [Rockstar North]
# 1025                             [Bethesda Game Studios]
# 4712   [Studio Wildcard, Instinct Games, Efecto Studi...
# 10                                               [Valve]
# 3362                             [Smartly Dressed Games]
# 1772                               [Grinding Gear Games]
# 5390                                        [Playsaurus]
# 2016                                 [Facepunch Studios]
# 1727                              [Gaijin Entertainment]
# 1467                   [OVERKILL - a Starbreeze Studio.]
# 1127                               [Bohemia Interactive]
# 5235                                  [Ubisoft Montreal]
# 12965                                 [CAPCOM Co., Ltd.]
#
#                         publisher              platforms  required_age  \
# 22                        [Valve]  [windows, mac, linux]             0
# 12836          [PUBG Corporation]              [windows]             0
# 25                        [Valve]  [windows, mac, linux]             0
# 0                         [Valve]  [windows, mac, linux]             0
# 19                        [Valve]  [windows, mac, linux]             0
# 121                       [Valve]  [windows, mac, linux]             0
# 1634           [Digital Extremes]              [windows]            16
# 2478             [Rockstar Games]              [windows]            18
# 1025         [Bethesda Softworks]              [windows]            16
# 4712            [Studio Wildcard]  [windows, mac, linux]             0
# 10                        [Valve]  [windows, mac, linux]             0
# 3362      [Smartly Dressed Games]  [windows, mac, linux]             0
# 1772        [Grinding Gear Games]              [windows]             0
# 5390                 [Playsaurus]         [windows, mac]             0
# 2016          [Facepunch Studios]         [windows, mac]            18
# 1727       [Gaijin Entertainment]  [windows, mac, linux]             0
# 1467   [Starbreeze Publishing AB]       [windows, linux]            18
# 1127        [Bohemia Interactive]              [windows]             0
# 5235                    [Ubisoft]              [windows]             0
# 12965          [CAPCOM Co., Ltd.]              [windows]             0
#
#                                               categories  \
# 22     [Multi-player, Co-op, Steam Trading Cards, Ste...
# 12836         [Multi-player, Online Multi-Player, Stats]
# 25     [Multi-player, Steam Achievements, Full contro...
# 0      [Multi-player, Online Multi-Player, Local Mult...
# 19     [Multi-player, Cross-Platform Multiplayer, Ste...
# 121    [Single-player, Multi-player, Co-op, Cross-Pla...
# 1634   [Single-player, Multi-player, Co-op, Steam Tra...
# 2478   [Single-player, Multi-player, Steam Achievemen...
# 1025   [Single-player, Steam Achievements, Steam Trad...
# 4712   [Single-player, Multi-player, MMO, Co-op, Stea...
# 10     [Multi-player, Cross-Platform Multiplayer, Ste...
# 3362   [Single-player, Online Multi-Player, Online Co...
# 1772   [Single-player, Multi-player, Online Multi-Pla...
# 5390   [Single-player, Steam Achievements, Steam Trad...
# 2016   [Multi-player, Online Multi-Player, MMO, Co-op...
# 1727   [Single-player, MMO, Co-op, Cross-Platform Mul...
# 1467   [Single-player, Multi-player, Co-op, Online Co...
# 1127   [Single-player, Multi-player, Online Multi-Pla...
# 5235   [Single-player, Multi-player, Co-op, Steam Tra...
# 12965  [Single-player, Multi-player, Co-op, Steam Ach...
#
#                                                   genres  \
# 22                      [Action, Free to Play, Strategy]
# 12836         [Action, Adventure, Massively Multiplayer]
# 25                                [Action, Free to Play]
# 0                                               [Action]
# 19                                [Action, Free to Play]
# 121                                  [Indie, Simulation]
# 1634                              [Action, Free to Play]
# 2478                                 [Action, Adventure]
# 1025                                               [RPG]
# 4712   [Action, Adventure, Indie, Massively Multiplay...
# 10                                              [Action]
# 3362    [Action, Adventure, Casual, Free to Play, Indie]
# 1772   [Action, Adventure, Free to Play, Indie, Massi...
# 5390   [Adventure, Casual, Free to Play, Indie, RPG, ...
# 2016   [Action, Adventure, Indie, Massively Multiplay...
# 1727   [Action, Free to Play, Massively Multiplayer, ...
# 1467                                       [Action, RPG]
# 1127                      [Action, Simulation, Strategy]
# 5235                                            [Action]
# 12965                                           [Action]
#
#                                     steamspy_tags  achievements  \
# 22                 [Free to Play, MOBA, Strategy]             0
# 12836            [Survival, Shooter, Multiplayer]            37
# 25                    [FPS, Multiplayer, Shooter]           167
# 0                      [Action, FPS, Multiplayer]             0
# 19               [Free to Play, Multiplayer, FPS]           520
# 121                 [Sandbox, Multiplayer, Funny]            29
# 1634                [Free to Play, Action, Co-op]           187
# 2478            [Open World, Action, Multiplayer]            77
# 1025                   [Open World, RPG, Fantasy]            75
# 4712          [Survival, Open World, Multiplayer]            32
# 10                     [Action, FPS, Multiplayer]           147
# 3362            [Free to Play, Survival, Zombies]            46
# 1772   [Free to Play, Action RPG, Hack and Slash]           120
# 5390              [Clicker, Free to Play, Casual]           111
# 2016            [Survival, Crafting, Multiplayer]            48
# 1727    [Free to Play, World War II, Multiplayer]            46
# 1467                         [Co-op, Action, FPS]          1130
# 1127          [Simulation, Military, Multiplayer]           104
# 5235                 [FPS, Multiplayer, Tactical]             0
# 12965              [Action, Hunting, Multiplayer]            50
#
#        positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 22               863507            142079             23944              801
# 12836            496184            487076             22938            12434
# 25              2644404            402313             22494             6502
# 0                124534              3339             17612              317
# 19               515879             34036              8495              623
# 121              363721             16433             12422             1875
# 1634             226541             20268              5845              394
# 2478             329061            139308              9837             4834
# 1025             237303             14951              7089             3885
# 4712             145035             66603             14154             1470
# 10                76640              3497              6842              400
# 3362             292574             31482              3248              413
# 1772              71593              6117              5263              492
# 5390              42530              4734              9742              463
# 2016             220370             53709              9352             2234
# 1727              83852             22166              4200              297
# 1467             308657             56523              3975              890
# 1127             105034             12524             18823             3621
# 5235             251178             59620              7504             2543
# 12965             72029             35294              6512             5372
#
#        price  owners_low_bound  owners_high_bound  total_ratings  \
# 22      0.00         100000000          200000000        1005586
# 12836  26.99          50000000          100000000         983260
# 25      0.00          50000000          100000000        3046717
# 0       7.19          10000000           20000000         127873
# 19      0.00          20000000           50000000         549915
# 121     6.99          10000000           20000000         380154
# 1634    0.00          20000000           50000000         246809
# 2478   24.99          10000000           20000000         468369
# 1025    9.99          10000000           20000000         252254
# 4712   44.99           5000000           10000000         211638
# 10      7.19          10000000           20000000          80137
# 3362    0.00          20000000           50000000         324056
# 1772    0.00          10000000           20000000          77710
# 5390    0.00           5000000           10000000          47264
# 2016   27.79           5000000           10000000         274079
# 1727    0.00          10000000           20000000         106018
# 1467    7.49          10000000           20000000         365180
# 1127   29.99           2000000            5000000         117558
# 5235   16.99           5000000           10000000         310798
# 12965  49.99           5000000           10000000         107323
#
#        rating_ratio     rating  release_year  linux  mac  windows  \
# 22         0.858710  85.201281          2013      1    1        1
# 12836      0.504632  50.066901          2017      0    0        1
# 25         0.867952  86.310312          2012      1    1        1
# 0          0.973888  95.975678          2000      1    1        1
# 19         0.938107  92.933233          2007      1    1        1
# 121        0.956773  94.677179          2006      1    1        1
# 1634       0.917880  90.695302          2013      0    0        1
# 2478       0.702568  69.567115          2015      0    0        1
# 1025       0.940730  92.960488          2011      0    0        1
# 4712       0.685298  67.675307          2017      1    1        1
# 10         0.956362  94.038910          2004      1    1        1
# 3362       0.902850  89.294812          2017      1    1        1
# 1772       0.921284  90.575389          2013      0    0        1
# 5390       0.899839  88.222113          2015      0    1        1
# 2016       0.804038  79.476392          2018      0    1        1
# 1727       0.790922  77.877967          2013      1    1        1
# 1467       0.845219  83.627633          2013      1    0        1
# 1127       0.893465  88.016851          2013      0    0        1
# 5235       0.808171  79.919544          2015      0    0        1
# 12965      0.671142  66.087643          2018      0    0        1
#
#             top_tag  type  total_playtime  estimated_revenue
# 22     Free to Play  Free   2394400000000       0.000000e+00
# 12836      Survival  Paid   1146900000000       1.349500e+09
# 25              FPS  Free   1124700000000       0.000000e+00
# 0            Action  Paid    176120000000       7.190000e+07
# 19     Free to Play  Free    169900000000       0.000000e+00
# 121         Sandbox  Paid    124220000000       6.990000e+07
# 1634   Free to Play  Free    116900000000       0.000000e+00
# 2478     Open World  Paid     98370000000       2.499000e+08
# 1025     Open World  Paid     70890000000       9.990000e+07
# 4712       Survival  Paid     70770000000       2.249500e+08
# 10           Action  Paid     68420000000       7.190000e+07
# 3362   Free to Play  Free     64960000000       0.000000e+00
# 1772   Free to Play  Free     52630000000       0.000000e+00
# 5390        Clicker  Free     48710000000       0.000000e+00
# 2016       Survival  Paid     46760000000       1.389500e+08
# 1727   Free to Play  Free     42000000000       0.000000e+00
# 1467          Co-op  Paid     39750000000       7.490000e+07
# 1127     Simulation  Paid     37646000000       5.998000e+07
# 5235            FPS  Paid     37520000000       8.495000e+07
# 12965        Action  Paid     32560000000       2.499500e+08

# %%
data = pDF.sort_values(by='total_playtime',ascending=False).head(20)

ax = data.plot(x='name', y='total_playtime', kind='bar', stacked=False)
ax.set_xlabel('')
ax.set_ylabel('sum(average_playtime*owners_lower_bound)')
ax.set_title('total Playtime combined')
sns.despine()
plt.show()

# %%
top3Playtime = pDF.sort_values(by='total_playtime',ascending=False).head(3)[('total_playtime')].sum()
allOtherPlaytime = pDF.sort_values(by='total_playtime',ascending=True).head((27075-3))[('total_playtime')].sum()

totalPlaytimeAll = pDF['total_playtime'].sum()
print("top3Playtime:",top3Playtime*100/totalPlaytimeAll)
print("allOtherPlaytime:",allOtherPlaytime*100/totalPlaytimeAll)
# Out:
# top3Playtime: 59.700122624768376
# allOtherPlaytime: 40.299877375231624

# %% [markdown]
# ## Insight 2

# %%
tptPDF = pDF.sort_values('total_playtime',ascending=False).head(math.ceil(27075*0.01))
tptPDF
# Out:
#         appid                                           name release_date  \
# 22        570                                         Dota 2   2013-07-09
# 12836  578080                  PLAYERUNKNOWN'S BATTLEGROUNDS   2017-12-21
# 25        730               Counter-Strike: Global Offensive   2012-08-21
# 0          10                                 Counter-Strike   2000-11-01
# 19        440                                Team Fortress 2   2007-10-10
# ...       ...                                            ...          ...
# 6433   391540                                      Undertale   2015-09-15
# 5553   367500                    Dragon's Dogma: Dark Arisen   2016-01-15
# 1773   239030                                 Papers, Please   2013-08-08
# 357     15370  Heroes of Might & Magic V: Tribes of the East   2008-10-10
# 589     32370      STAR WARS™ - Knights of the Old Republic™   2009-09-05
#
#        english                           developer  \
# 22           1                             [Valve]
# 12836        1                  [PUBG Corporation]
# 25           1  [Valve, Hidden Path Entertainment]
# 0            1                             [Valve]
# 19           1                             [Valve]
# ...        ...                                 ...
# 6433         1                           [tobyfox]
# 5553         1                            [Capcom]
# 1773         1                        [Lucas Pope]
# 357          1                             [Nival]
# 589          1              [BioWare, Aspyr (Mac)]
#
#                                                publisher  \
# 22                                               [Valve]
# 12836                                 [PUBG Corporation]
# 25                                               [Valve]
# 0                                                [Valve]
# 19                                               [Valve]
# ...                                                  ...
# 6433                                           [tobyfox]
# 5553                                            [Capcom]
# 1773                                              [3909]
# 357                                            [Ubisoft]
# 589    [LucasArts, Aspyr (Mac), Disney Interactive, L...
#
#                    platforms  required_age  \
# 22     [windows, mac, linux]             0
# 12836              [windows]             0
# 25     [windows, mac, linux]             0
# 0      [windows, mac, linux]             0
# 19     [windows, mac, linux]             0
# ...                      ...           ...
# 6433   [windows, mac, linux]             0
# 5553               [windows]             0
# 1773   [windows, mac, linux]             0
# 357                [windows]             0
# 589           [windows, mac]             0
#
#                                               categories  \
# 22     [Multi-player, Co-op, Steam Trading Cards, Ste...
# 12836         [Multi-player, Online Multi-Player, Stats]
# 25     [Multi-player, Steam Achievements, Full contro...
# 0      [Multi-player, Online Multi-Player, Local Mult...
# 19     [Multi-player, Cross-Platform Multiplayer, Ste...
# ...                                                  ...
# 6433                [Single-player, Steam Trading Cards]
# 5553   [Single-player, Steam Achievements, Full contr...
# 1773   [Single-player, Steam Achievements, Steam Trad...
# 357                                      [Single-player]
# 589                         [Single-player, Steam Cloud]
#
#                                            genres  \
# 22               [Action, Free to Play, Strategy]
# 12836  [Action, Adventure, Massively Multiplayer]
# 25                         [Action, Free to Play]
# 0                                        [Action]
# 19                         [Action, Free to Play]
# ...                                           ...
# 6433                                 [Indie, RPG]
# 5553                     [Action, Adventure, RPG]
# 1773                           [Adventure, Indie]
# 357                                    [Strategy]
# 589                              [Adventure, RPG]
#
#                                         steamspy_tags  achievements  \
# 22                     [Free to Play, MOBA, Strategy]             0
# 12836                [Survival, Shooter, Multiplayer]            37
# 25                        [FPS, Multiplayer, Shooter]           167
# 0                          [Action, FPS, Multiplayer]             0
# 19                   [Free to Play, Multiplayer, FPS]           520
# ...                                               ...           ...
# 6433   [Great Soundtrack, Story Rich, Choices Matter]             0
# 5553       [RPG, Open World, Character Customization]            59
# 1773                   [Indie, Political, Simulation]            13
# 357       [Strategy, Turn-Based Strategy, Turn-Based]             0
# 589                          [RPG, Star Wars, Sci-fi]             0
#
#        positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 22               863507            142079             23944              801
# 12836            496184            487076             22938            12434
# 25              2644404            402313             22494             6502
# 0                124534              3339             17612              317
# 19               515879             34036              8495              623
# ...                 ...               ...               ...              ...
# 6433              97832              4496               679              443
# 5553              12856              1688              1355             1137
# 1773              25587              1103               674              214
# 357                 759                66              6679             6679
# 589               11569              1590               660              400
#
#        price  owners_low_bound  owners_high_bound  total_ratings  \
# 22      0.00         100000000          200000000        1005586
# 12836  26.99          50000000          100000000         983260
# 25      0.00          50000000          100000000        3046717
# 0       7.19          10000000           20000000         127873
# 19      0.00          20000000           50000000         549915
# ...      ...               ...                ...            ...
# 6433    6.99           2000000            5000000         102328
# 5553   23.99           1000000            2000000          14544
# 1773    6.99           2000000            5000000          26690
# 357     8.59            200000             500000            825
# 589     7.19           2000000            5000000          13159
#
#        rating_ratio     rating  release_year  linux  mac  windows  \
# 22         0.858710  85.201281          2013      1    1        1
# 12836      0.504632  50.066901          2017      0    0        1
# 25         0.867952  86.310312          2012      1    1        1
# 0          0.973888  95.975678          2000      1    1        1
# 19         0.938107  92.933233          2007      1    1        1
# ...             ...        ...           ...    ...  ...      ...
# 6433       0.956063  94.122755          2015      1    1        1
# 5553       0.883938  85.926151          2016      0    0        1
# 1773       0.958674  93.638047          2013      1    1        1
# 357        0.920000  85.909410          2008      0    0        1
# 589        0.879170  85.387581          2009      0    1        1
#
#                 top_tag  type  total_playtime  estimated_revenue
# 22         Free to Play  Free   2394400000000       0.000000e+00
# 12836          Survival  Paid   1146900000000       1.349500e+09
# 25                  FPS  Free   1124700000000       0.000000e+00
# 0                Action  Paid    176120000000       7.190000e+07
# 19         Free to Play  Free    169900000000       0.000000e+00
# ...                 ...   ...             ...                ...
# 6433   Great Soundtrack  Paid      1358000000       1.398000e+07
# 5553                RPG  Paid      1355000000       2.399000e+07
# 1773              Indie  Paid      1348000000       1.398000e+07
# 357            Strategy  Paid      1335800000       1.718000e+06
# 589                 RPG  Paid      1320000000       1.438000e+07
#
# [271 rows x 30 columns]

# %%
pDF.sort_values(by='estimated_revenue',ascending=False).head(20)
# Out:
#         appid                              name release_date  english  \
# 12836  578080     PLAYERUNKNOWN'S BATTLEGROUNDS   2017-12-21        1
# 12965  582010             MONSTER HUNTER: WORLD   2018-08-09        1
# 2478   271590                Grand Theft Auto V   2015-04-13        1
# 4712   346110             ARK: Survival Evolved   2017-08-27        1
# 22458  863550                         HITMAN™ 2   2018-11-13        1
# 2016   252490                              Rust   2018-02-08        1
# 2964   292030         The Witcher® 3: Wild Hunt   2015-05-18        1
# 2087   255710                  Cities: Skylines   2015-03-10        1
# 2878   289070      Sid Meier’s Civilization® VI   2016-10-20        1
# 5916   377160                         Fallout 4   2015-11-09        1
# 258     10180  Call of Duty®: Modern Warfare® 2   2009-11-11        1
# 903     49520                     Borderlands 2   2012-09-20        1
# 222      8930       Sid Meier's Civilization® V   2010-09-23        1
# 1025    72850       The Elder Scrolls V: Skyrim   2011-11-10        1
# 20828  814380        Sekiro™: Shadows Die Twice   2019-03-21        1
# 1479   219640        Chivalry: Medieval Warfare   2012-10-16        1
# 5235   359550   Tom Clancy's Rainbow Six® Siege   2015-12-01        1
# 5472   365590        Tom Clancy’s The Division™   2016-03-07        1
# 5817   374320                   DARK SOULS™ III   2016-04-11        1
# 1213   202970       Call of Duty®: Black Ops II   2012-11-12        1
#
#                                                developer  \
# 12836                                 [PUBG Corporation]
# 12965                                 [CAPCOM Co., Ltd.]
# 2478                                    [Rockstar North]
# 4712   [Studio Wildcard, Instinct Games, Efecto Studi...
# 22458                               [IO Interactive A/S]
# 2016                                 [Facepunch Studios]
# 2964                                    [CD PROJEKT RED]
# 2087                               [Colossal Order Ltd.]
# 2878         [Firaxis Games, Aspyr (Mac), Aspyr (Linux)]
# 5916                             [Bethesda Game Studios]
# 258                         [Infinity Ward, Aspyr (Mac)]
# 903       [Gearbox Software, Aspyr (Mac), Aspyr (Linux)]
# 222          [Firaxis Games, Aspyr (Mac), Aspyr (Linux)]
# 1025                             [Bethesda Game Studios]
# 20828                                     [FromSoftware]
# 1479                               [Torn Banner Studios]
# 5235                                  [Ubisoft Montreal]
# 5472                             [Massive Entertainment]
# 5817                                [FromSoftware, Inc.]
# 1213                                          [Treyarch]
#
#                                                publisher  \
# 12836                                 [PUBG Corporation]
# 12965                                 [CAPCOM Co., Ltd.]
# 2478                                    [Rockstar Games]
# 4712                                   [Studio Wildcard]
# 22458            [Warner Bros Interactive Entertainment]
# 2016                                 [Facepunch Studios]
# 2964                                    [CD PROJEKT RED]
# 2087                               [Paradox Interactive]
# 2878                    [2K, Aspyr (Mac), Aspyr (Linux)]
# 5916                                [Bethesda Softworks]
# 258                            [Activision, Aspyr (Mac)]
# 903                     [2K, Aspyr (Mac), Aspyr (Linux)]
# 222                     [2K, Aspyr (Mac), Aspyr (Linux)]
# 1025                                [Bethesda Softworks]
# 20828  [Activision (Excluding Japan and Asia), FromSo...
# 1479                               [Torn Banner Studios]
# 5235                                           [Ubisoft]
# 5472                                           [Ubisoft]
# 5817    [FromSoftware, Inc., BANDAI NAMCO Entertainment]
# 1213                                        [Activision]
#
#                    platforms  required_age  \
# 12836              [windows]             0
# 12965              [windows]             0
# 2478               [windows]            18
# 4712   [windows, mac, linux]             0
# 22458              [windows]             0
# 2016          [windows, mac]            18
# 2964               [windows]             0
# 2087   [windows, mac, linux]             0
# 2878   [windows, mac, linux]             0
# 5916               [windows]            18
# 258           [windows, mac]             0
# 903    [windows, mac, linux]            18
# 222    [windows, mac, linux]             0
# 1025               [windows]            16
# 20828              [windows]            18
# 1479   [windows, mac, linux]             0
# 5235               [windows]             0
# 5472               [windows]            18
# 5817               [windows]             0
# 1213               [windows]            18
#
#                                               categories  \
# 12836         [Multi-player, Online Multi-Player, Stats]
# 12965  [Single-player, Multi-player, Co-op, Steam Ach...
# 2478   [Single-player, Multi-player, Steam Achievemen...
# 4712   [Single-player, Multi-player, MMO, Co-op, Stea...
# 22458  [Single-player, Online Multi-Player, Online Co...
# 2016   [Multi-player, Online Multi-Player, MMO, Co-op...
# 2964   [Single-player, Steam Achievements, Full contr...
# 2087   [Single-player, Steam Achievements, Steam Trad...
# 2878   [Single-player, Multi-player, Steam Achievemen...
# 5916   [Single-player, Steam Achievements, Full contr...
# 258    [Single-player, Multi-player, Co-op, Steam Ach...
# 903    [Single-player, Co-op, Steam Achievements, Ful...
# 222    [Single-player, Multi-player, Steam Achievemen...
# 1025   [Single-player, Steam Achievements, Steam Trad...
# 20828  [Single-player, Steam Achievements, Full contr...
# 1479   [Multi-player, Steam Achievements, Full contro...
# 5235   [Single-player, Multi-player, Co-op, Steam Tra...
# 5472   [Single-player, Multi-player, Co-op, Steam Tra...
# 5817   [Single-player, Multi-player, Co-op, Steam Ach...
# 1213   [Single-player, Multi-player, Co-op, Steam Ach...
#
#                                                   genres  \
# 12836         [Action, Adventure, Massively Multiplayer]
# 12965                                           [Action]
# 2478                                 [Action, Adventure]
# 4712   [Action, Adventure, Indie, Massively Multiplay...
# 22458                                           [Action]
# 2016   [Action, Adventure, Indie, Massively Multiplay...
# 2964                                               [RPG]
# 2087                              [Simulation, Strategy]
# 2878                                          [Strategy]
# 5916                                               [RPG]
# 258                                             [Action]
# 903                                        [Action, RPG]
# 222                                           [Strategy]
# 1025                                               [RPG]
# 20828                                [Action, Adventure]
# 1479                                     [Action, Indie]
# 5235                                            [Action]
# 5472                            [Action, Adventure, RPG]
# 5817                                            [Action]
# 1213                                            [Action]
#
#                                          steamspy_tags  achievements  \
# 12836                 [Survival, Shooter, Multiplayer]            37
# 12965                   [Action, Hunting, Multiplayer]            50
# 2478                 [Open World, Action, Multiplayer]            77
# 4712               [Survival, Open World, Multiplayer]            32
# 22458                      [Stealth, Action, Assassin]           125
# 2016                 [Survival, Crafting, Multiplayer]            48
# 2964                     [Open World, RPG, Story Rich]            78
# 2087              [City Builder, Simulation, Building]            97
# 2878       [Strategy, Turn-Based Strategy, Historical]           241
# 5916       [Open World, Post-apocalyptic, Exploration]            84
# 258                         [Action, FPS, Multiplayer]            50
# 903                                  [FPS, Co-op, RPG]            69
# 222        [Turn-Based Strategy, Strategy, Turn-Based]           286
# 1025                        [Open World, RPG, Fantasy]            75
# 20828                  [Action, Souls-like, Difficult]            34
# 1479                   [Medieval, Multiplayer, Action]            49
# 5235                      [FPS, Multiplayer, Tactical]             0
# 5472   [Open World, Multiplayer, Third-Person Shooter]             0
# 5817                    [Dark Fantasy, Difficult, RPG]            43
# 1213                        [Action, Multiplayer, FPS]            35
#
#        positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 12836            496184            487076             22938            12434
# 12965             72029             35294              6512             5372
# 2478             329061            139308              9837             4834
# 4712             145035             66603             14154             1470
# 22458             10814              1756               636              514
# 2016             220370             53709              9352             2234
# 2964             202930              4798              3068             2002
# 2087              67553              6005              3225              444
# 2878              39127             18325              3371             2390
# 5916             110376             45377              4822             2904
# 258               30006              2826               999              580
# 903              144595             11021              3276             1139
# 222              129030              5565              4760             1797
# 1025             237303             14951              7089             3885
# 20828             21504              3019              2059             2212
# 1479              51499             10939               675              293
# 5235             251178             59620              7504             2543
# 5472              49832             25607              4252             1952
# 5817             100412              9953              4222             1776
# 1213              25827              4658               524              400
#
#        price  owners_low_bound  owners_high_bound  total_ratings  \
# 12836  26.99          50000000          100000000         983260
# 12965  49.99           5000000           10000000         107323
# 2478   24.99          10000000           20000000         468369
# 4712   44.99           5000000           10000000         211638
# 22458  44.99           5000000           10000000          12570
# 2016   27.79           5000000           10000000         274079
# 2964   24.99           5000000           10000000         207728
# 2087   22.99           5000000           10000000          73558
# 2878   49.99           2000000            5000000          57452
# 5916   19.99           5000000           10000000         155753
# 258    19.99           5000000           10000000          32832
# 903    19.99           5000000           10000000         155616
# 222    19.99           5000000           10000000         134595
# 1025    9.99          10000000           20000000         252254
# 20828  49.90           2000000            5000000          24523
# 1479   18.99           5000000           10000000          62438
# 5235   16.99           5000000           10000000         310798
# 5472   41.99           2000000            5000000          75439
# 5817   39.99           2000000            5000000         110365
# 1213   39.99           2000000            5000000          30485
#
#        rating_ratio     rating  release_year  linux  mac  windows  \
# 12836      0.504632  50.066901          2017      0    0        1
# 12965      0.671142  66.087643          2018      0    0        1
# 2478       0.702568  69.567115          2015      0    0        1
# 4712       0.685298  67.675307          2017      1    1        1
# 22458      0.860302  83.520727          2018      0    0        1
# 2016       0.804038  79.476392          2018      0    1        1
# 2964       0.976902  96.465364          2015      0    0        1
# 2087       0.918364  90.262459          2015      1    1        1
# 2878       0.681038  66.846489          2016      1    1        1
# 5916       0.708661  69.897041          2015      0    0        1
# 258        0.913925  89.395738          2009      0    1        1
# 903        0.929178  91.646945          2012      1    1        1
# 222        0.958654  94.495630          2010      1    1        1
# 1025       0.940730  92.960488          2011      0    0        1
# 20828      0.876891  85.597323          2019      0    0        1
# 1479       0.824802  80.995161          2012      1    1        1
# 5235       0.808171  79.919544          2015      0    0        1
# 5472       0.660560  64.932506          2016      0    0        1
# 5817       0.909817  89.601741          2016      0    0        1
# 1213       0.847204  82.827536          2012      0    0        1
#
#                    top_tag  type  total_playtime  estimated_revenue
# 12836             Survival  Paid   1146900000000       1.349500e+09
# 12965               Action  Paid     32560000000       2.499500e+08
# 2478            Open World  Paid     98370000000       2.499000e+08
# 4712              Survival  Paid     70770000000       2.249500e+08
# 22458              Stealth  Paid      3180000000       2.249500e+08
# 2016              Survival  Paid     46760000000       1.389500e+08
# 2964            Open World  Paid     15340000000       1.249500e+08
# 2087          City Builder  Paid     16125000000       1.149500e+08
# 2878              Strategy  Paid      6742000000       9.998000e+07
# 5916            Open World  Paid     24110000000       9.995000e+07
# 258                 Action  Paid      4995000000       9.995000e+07
# 903                    FPS  Paid     16380000000       9.995000e+07
# 222    Turn-Based Strategy  Paid     23800000000       9.995000e+07
# 1025            Open World  Paid     70890000000       9.990000e+07
# 20828               Action  Paid      4118000000       9.980000e+07
# 1479              Medieval  Paid      3375000000       9.495000e+07
# 5235                   FPS  Paid     37520000000       8.495000e+07
# 5472            Open World  Paid      8504000000       8.398000e+07
# 5817          Dark Fantasy  Paid      8444000000       7.998000e+07
# 1213                Action  Paid      1048000000       7.998000e+07

# %%
xCol = 'total_playtime'
yCol = 'rating' 

#data = pDF.sort_values(by='estimated_revenue',ascending=False).head(1)
data = topPDF.sort_values(by='total_playtime',ascending=True).head(len(topPDF.index)-50)

color =  np.array(['red','blue'])
plt.scatter(marker='.',x=data[xCol],y=data[yCol])
plt.xlabel(xCol)
plt.ylabel(yCol)
plt.title('Combination '+xCol+','+yCol +' ')
# Out:
# Text(0.5, 1.0, 'Combination total_playtime,rating ')

# %%
pDF[['total_playtime','type']]
# Out:
#        total_playtime  type
# 0        176120000000  Paid
# 1          1385000000  Paid
# 2           935000000  Paid
# 3          1290000000  Paid
# 4          3120000000  Paid
# ...               ...   ...
# 27070               0  Paid
# 27071               0  Paid
# 27072               0  Paid
# 27073               0  Paid
# 27074               0  Paid
#
# [27075 rows x 2 columns]

# %%
# IDEE:Scatter plot mit ratings * playtime rank, color: Playtime Gruppen (top 25,50, ...)
# je besser das rating desto höher ist das rating

# %%
topRatedGames = pDF.sort_values(by='rating',ascending=False).head(math.ceil(27000*0.1))

# %%
topRatedGamesGrouped = topRatedGames[['release_year','appid']].groupby('release_year').count()
allGamesPerYear = pDF[['release_year','appid']].groupby('release_year').count()
topRatedGamesGrouped

merged = allGamesPerYear
merged['released games'] = merged['appid']
merged['top 10% rated games'] = topRatedGamesGrouped['appid']
merged['percent'] = merged['top 10% rated games'] * 100 / merged['released games']
del merged['appid']
merged
# Out:
#               released games  top 10% rated games     percent
# release_year
# 1997                       1                    1  100.000000
# 1998                       1                    1  100.000000
# 1999                       2                    1   50.000000
# 2000                       2                    1   50.000000
# 2001                       4                    3   75.000000
# 2002                       1                    1  100.000000
# 2003                       3                    1   33.333333
# 2004                       6                    5   83.333333
# 2005                       6                    2   33.333333
# 2006                      48                   18   37.500000
# 2007                      93                   37   39.784946
# 2008                     145                   35   24.137931
# 2009                     305                   64   20.983607
# 2010                     238                   50   21.008403
# 2011                     239                   57   23.849372
# 2012                     320                   92   28.750000
# 2013                     418                  134   32.057416
# 2014                    1555                  240   15.434084
# 2015                    2597                  329   12.668464
# 2016                    4361                  458   10.502178
# 2017                    6357                  493    7.755230
# 2018                    8160                  526    6.446078
# 2019                    2213                  151    6.823317

# %%
ax = merged.plot(y=['released games','top 10% rated games'], kind='bar', stacked=False)
ax.set_xlabel('')
ax.set_ylabel('Count of released games')
ax.set_title('Released games vs. top 10% rated games')
plt.show()

# %%
ax = merged.plot(y=['percent'])
ax.set_xlabel('')
ax.set_ylabel('%')
ax.set_title('% of released games in the top 10% rated games all time')
plt.show()

# %%
pDF
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   2000-11-01        1
# 1           20       Team Fortress Classic   1999-04-01        1
# 2           30               Day of Defeat   2003-05-01        1
# 3           40          Deathmatch Classic   2001-06-01        1
# 4           50   Half-Life: Opposing Force   1999-11-01        1
# ...        ...                         ...          ...      ...
# 27070  1065230             Room of Pandora   2019-04-24        1
# 27071  1065570                   Cyber Gun   2019-04-23        1
# 27072  1065650            Super Star Blast   2019-04-24        1
# 27073  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 27074  1069460                   Rune Lord   2019-04-24        1
#
#                   developer               publisher              platforms  \
# 0                   [Valve]                 [Valve]  [windows, mac, linux]
# 1                   [Valve]                 [Valve]  [windows, mac, linux]
# 2                   [Valve]                 [Valve]  [windows, mac, linux]
# 3                   [Valve]                 [Valve]  [windows, mac, linux]
# 4        [Gearbox Software]                 [Valve]  [windows, mac, linux]
# ...                     ...                     ...                    ...
# 27070         [SHEN JIAWEI]           [SHEN JIAWEI]              [windows]
# 27071      [Semyon Maximov]      [BekkerDev Studio]              [windows]
# 27072         [EntwicklerX]           [EntwicklerX]              [windows]
# 27073  [Yustas Game Studio]  [Alawar Entertainment]         [windows, mac]
# 27074    [Adept Studios GD]  [Alawar Entertainment]         [windows, mac]
#
#        required_age                                         categories  \
# 0                 0  [Multi-player, Online Multi-Player, Local Mult...
# 1                 0  [Multi-player, Online Multi-Player, Local Mult...
# 2                 0           [Multi-player, Valve Anti-Cheat enabled]
# 3                 0  [Multi-player, Online Multi-Player, Local Mult...
# 4                 0  [Single-player, Multi-player, Valve Anti-Cheat...
# ...             ...                                                ...
# 27070             0                [Single-player, Steam Achievements]
# 27071             0                                    [Single-player]
# 27072             0  [Single-player, Multi-player, Co-op, Shared/Sp...
# 27073             0                       [Single-player, Steam Cloud]
# 27074             0                       [Single-player, Steam Cloud]
#
#                            genres                     steamspy_tags  \
# 0                        [Action]        [Action, FPS, Multiplayer]
# 1                        [Action]        [Action, FPS, Multiplayer]
# 2                        [Action]  [FPS, World War II, Multiplayer]
# 3                        [Action]        [Action, FPS, Multiplayer]
# 4                        [Action]             [FPS, Action, Sci-fi]
# ...                           ...                               ...
# 27070  [Adventure, Casual, Indie]        [Adventure, Indie, Casual]
# 27071  [Action, Adventure, Indie]        [Action, Indie, Adventure]
# 27072     [Action, Casual, Indie]           [Action, Indie, Casual]
# 27073  [Adventure, Casual, Indie]        [Indie, Casual, Adventure]
# 27074  [Adventure, Casual, Indie]        [Indie, Casual, Adventure]
#
#        achievements  positive_ratings  negative_ratings  average_playtime  \
# 0                 0            124534              3339             17612
# 1                 0              3318               633               277
# 2                 0              3416               398               187
# 3                 0              1273               267               258
# 4                 0              5250               288               624
# ...             ...               ...               ...               ...
# 27070             7                 3                 0                 0
# 27071             0                 8                 1                 0
# 27072            24                 0                 1                 0
# 27073             0                 2                 0                 0
# 27074             0                 4                 0                 0
#
#        median_playtime  price  owners_low_bound  owners_high_bound  \
# 0                  317   7.19          10000000           20000000
# 1                   62   3.99           5000000           10000000
# 2                   34   3.99           5000000           10000000
# 3                  184   3.99           5000000           10000000
# 4                  415   3.99           5000000           10000000
# ...                ...    ...               ...                ...
# 27070                0   2.09                 0              20000
# 27071                0   1.69                 0              20000
# 27072                0   3.99                 0              20000
# 27073                0   5.19                 0              20000
# 27074                0   5.19                 0              20000
#
#        total_ratings  rating_ratio     rating  release_year  linux  mac  \
# 0             127873      0.973888  95.975678          2000      1    1
# 1               3951      0.839787  80.508259          1999      1    1
# 2               3814      0.895648  85.823915          2003      1    1
# 3               1540      0.826623  78.126542          2001      1    1
# 4               5538      0.947996  91.260480          1999      1    1
# ...              ...           ...        ...           ...    ...  ...
# 27070              3      1.000000  67.059371          2019      0    0
# 27071              9      0.888889  66.666667          2019      0    0
# 27072              1      0.000000   0.000000          2019      0    0
# 27073              2      1.000000  64.079515          2019      0    1
# 27074              4      1.000000  69.199408          2019      0    1
#
#        windows    top_tag  type  total_playtime  estimated_revenue
# 0            1     Action  Paid    176120000000         71900000.0
# 1            1     Action  Paid      1385000000         19950000.0
# 2            1        FPS  Paid       935000000         19950000.0
# 3            1     Action  Paid      1290000000         19950000.0
# 4            1        FPS  Paid      3120000000         19950000.0
# ...        ...        ...   ...             ...                ...
# 27070        1  Adventure  Paid               0                0.0
# 27071        1     Action  Paid               0                0.0
# 27072        1     Action  Paid               0                0.0
# 27073        1      Indie  Paid               0                0.0
# 27074        1      Indie  Paid               0                0.0
#
# [27075 rows x 30 columns]

# %%
pDF['owners_low_bound']
# Out:
# 0        10000000
# 1         5000000
# 2         5000000
# 3         5000000
# 4         5000000
#            ...
# 27070           0
# 27071           0
# 27072           0
# 27073           0
# 27074           0
# Name: owners_low_bound, Length: 27075, dtype: int64

# %%
# Zusammenhang developer/publisher zu rating

# %%
windowsCount = pDF[['windows']].groupby(['windows']).sum()

# %%
pDF[['windows','linux','mac']].sum().plot(kind='bar', stacked=False)
# Out:
# <AxesSubplot:>

# %%
def andFilter(row,column,values):
    return set(values).issubset(set(row[column])) 

def orFilter(row,column,values):
    return any(item in row[column] for item in values)

def notFilter(row,column,values):
    return not (any(item in row[column] for item in values))
  
def equalsFilter(row,column,values):
    return sorted(row[column]) == sorted(values)

def smallerFilter(row,column,value):
    return row[column] < value

def biggerFilter(row,column,value):
    return row[column] > value

def sameFilter(row,column,value):
    return row[column] == value

def notSameFilter(row,column,values):
    return row[column] != values

def multipleFilter(df, funcArr):
    erg = df
    for func in funcArr:
        erg = erg[erg.apply(lambda row: func(row), axis=1)]
    return erg


#multipleFilter(pDF,[
#    lambda row: orFilter(row,'platforms',['linux','mac']),
#    lambda row: biggerFilter(row,'owners_low_bound',0),
#    lambda row: smallerFilter(row,'price',5),
#    lambda row: orFilter(row,'categories',['Single-player']),
#    lambda row: notFilter(row,'categories',['Multi-player']),
#])


    #return df[df.apply(lambda row: func(row), axis=1)]

#multipleFilter(pDF,[
#    lambda row: orFilter(row,'categories',['Single-player']),
#    lambda row: equalsFilter(row,'platforms',['windows','linux','mac'])
#])

#pDF[pDF.apply(lambda row: orFilter(row,'categories',['Single-player']), axis=1)]

#pDF[pDF.apply(lambda row: andFilter(row,'platforms',['windows','linux','mac']), axis=1)]
#pDF[pDF.apply(lambda row: orFilter(row,'platforms',['linux','mac']), axis=1)]
#pDF[pDF.apply(lambda row: isFilter(row,'platforms',['mac','windows']), axis=1)]

# %%
def getAllCombinations(stuff):
    erg = []
    for L in range(0, len(stuff)+1):
        for subset in itertools.combinations(stuff, L):
            erg.insert(0,list(subset))
    erg.pop()
    return erg

getAllCombinations(['windows','linux','mac'])
# Out:
# [['windows', 'linux', 'mac'],
#  ['linux', 'mac'],
#  ['windows', 'mac'],
#  ['windows', 'linux'],
#  ['mac'],
#  ['linux'],
#  ['windows']]

# %%
multipleFilter(pDF,[
    lambda row: orFilter(row,'platforms',['linux','mac']),
    lambda row: orFilter(row,'categories',['Single-player']),
    lambda row: notFilter(row,'categories',['Multi-player']),
])
# Out:
#          appid                              name release_date  english  \
# 8          130             Half-Life: Blue Shift   2001-06-01        1
# 9          220                       Half-Life 2   2004-11-16        1
# 11         280                 Half-Life: Source   2004-06-01        1
# 14         340           Half-Life 2: Lost Coast   2005-10-27        1
# 16         380          Half-Life 2: Episode One   2006-06-01        1
# ...        ...                               ...          ...      ...
# 27019  1055970   Argonauts Agency: Pandora's Box   2019-04-17        1
# 27035  1057710           Funny Bunny: Adventures   2019-04-24        1
# 27049  1059710  New Yankee 6: In Pharaoh's Court   2019-04-03        1
# 27073  1066700        New Yankee 7: Deer Hunters   2019-04-17        1
# 27074  1069460                         Rune Lord   2019-04-24        1
#
#                    developer               publisher              platforms  \
# 8         [Gearbox Software]                 [Valve]  [windows, mac, linux]
# 9                    [Valve]                 [Valve]  [windows, mac, linux]
# 11                   [Valve]                 [Valve]  [windows, mac, linux]
# 14                   [Valve]                 [Valve]  [windows, mac, linux]
# 16                   [Valve]                 [Valve]  [windows, mac, linux]
# ...                      ...                     ...                    ...
# 27019            [Workroom7]             [Workroom7]         [windows, mac]
# 27035  [mPower Games Studio]   [mPower Games Studio]  [windows, mac, linux]
# 27049   [Yustas Game Studio]  [Alawar Entertainment]         [windows, mac]
# 27073   [Yustas Game Studio]  [Alawar Entertainment]         [windows, mac]
# 27074     [Adept Studios GD]  [Alawar Entertainment]         [windows, mac]
#
#        required_age                                         categories  \
# 8                 0                                    [Single-player]
# 9                 0  [Single-player, Steam Achievements, Steam Trad...
# 11                0                                    [Single-player]
# 14                0              [Single-player, Commentary available]
# 16                0  [Single-player, Steam Achievements, Captions a...
# ...             ...                                                ...
# 27019             0   [Single-player, Steam Achievements, Steam Cloud]
# 27035             0                [Single-player, Steam Achievements]
# 27049             0                       [Single-player, Steam Cloud]
# 27073             0                       [Single-player, Steam Cloud]
# 27074             0                       [Single-player, Steam Cloud]
#
#                                    genres                   steamspy_tags  \
# 8                                [Action]           [FPS, Action, Sci-fi]
# 9                                [Action]           [FPS, Action, Sci-fi]
# 11                               [Action]           [FPS, Action, Sci-fi]
# 14                               [Action]     [FPS, Action, Singleplayer]
# 16                               [Action]           [FPS, Action, Sci-fi]
# ...                                   ...                             ...
# 27019      [Casual, Simulation, Strategy]  [Strategy, Casual, Simulation]
# 27035  [Action, Adventure, Casual, Indie]     [Casual, Adventure, Arcade]
# 27049          [Adventure, Casual, Indie]      [Indie, Casual, Adventure]
# 27073          [Adventure, Casual, Indie]      [Indie, Casual, Adventure]
# 27074          [Adventure, Casual, Indie]      [Indie, Casual, Adventure]
#
#        achievements  positive_ratings  negative_ratings  average_playtime  \
# 8                 0              3822               420               361
# 9                33             67902              2419               691
# 11                0              3767              1053               190
# 14                0              5783              1020                46
# 16               13              7908               517               281
# ...             ...               ...               ...               ...
# 27019            29                 1                 0                 0
# 27035            22                 3                 0                 0
# 27049             0                 2                 0                 0
# 27073             0                 2                 0                 0
# 27074             0                 4                 0                 0
#
#        median_playtime  price  owners_low_bound  owners_high_bound  \
# 8                  205   3.99           5000000           10000000
# 9                  402   7.19          10000000           20000000
# 11                 214   0.00           2000000            5000000
# 14                  29   0.00          10000000           20000000
# 16                 184   5.79           5000000           10000000
# ...                ...    ...               ...                ...
# 27019                0   4.79                 0              20000
# 27035                0   7.19                 0              20000
# 27049                0   5.19                 0              20000
# 27073                0   5.19                 0              20000
# 27074                0   5.19                 0              20000
#
#        total_ratings  rating_ratio     rating  release_year  linux  mac  \
# 8               4242      0.900990  86.454395          2001      1    1
# 9              70321      0.965601  94.882618          2004      1    1
# 11              4820      0.781535  75.111355          2004      1    1
# 14              6803      0.850066  82.023667          2005      1    1
# 16              8425      0.938635  90.775077          2006      1    1
# ...              ...           ...        ...           ...    ...  ...
# 27019              1      1.000000  59.416365          2019      0    1
# 27035              3      1.000000  67.059371          2019      1    1
# 27049              2      1.000000  64.079515          2019      0    1
# 27073              2      1.000000  64.079515          2019      0    1
# 27074              4      1.000000  69.199408          2019      0    1
#
#        windows   top_tag  type  total_playtime  estimated_revenue
# 8            1       FPS  Paid      1805000000         19950000.0
# 9            1       FPS  Paid      6910000000         71900000.0
# 11           1       FPS  Free       380000000                0.0
# 14           1       FPS  Free       460000000                0.0
# 16           1       FPS  Paid      1405000000         28950000.0
# ...        ...       ...   ...             ...                ...
# 27019        1  Strategy  Paid               0                0.0
# 27035        1    Casual  Paid               0                0.0
# 27049        1     Indie  Paid               0                0.0
# 27073        1     Indie  Paid               0                0.0
# 27074        1     Indie  Paid               0                0.0
#
# [7222 rows x 30 columns]

# %%
multipleFilter(pDF,[
    lambda row: orFilter(row,'platforms',['linux','mac']),
    lambda row: orFilter(row,'categories',['Multi-player']),
    lambda row: notFilter(row,'categories',['Single-player'])
])[['price','release_date','average_playtime','rating','total_playtime','estimated_revenue']].mean(numeric_only=False)
# Out:
# price                                      4.21983
# release_date         2016-04-16 15:35:41.772151808
# average_playtime                              1472
# rating                                     63.5337
# total_playtime                         17336775611
# estimated_revenue                      2.75237e+06
# dtype: object

# %%
avgColumns = ['price','release_date','average_playtime','rating','total_playtime','estimated_revenue']
linuxMacResult = multipleFilter(pDF,[
    lambda row: orFilter(row,'platforms',['linux','mac'])
])[avgColumns].mean(numeric_only=False)

windowsResult = multipleFilter(pDF,[
    lambda row: orFilter(row,'platforms',['windows'])
])[avgColumns].mean(numeric_only=False)

windowsResult.to_frame(name='windowsResult').transpose()

#[windowsResult,linuxMacResult].to_frame(name='windowsResult').transpose()
pd.concat([windowsResult,linuxMacResult], axis=1,keys=['a','b']).transpose()
# Out:
#      price                  release_date average_playtime   rating  \
# a  6.07851 2016-12-31 15:01:52.508311808              149  58.8302
# b   6.2246 2016-09-29 10:24:19.582805248              233  64.1915
#
#   total_playtime estimated_revenue
# a      288722916            695414
# b      610963671            982496

# %%
def splitList(list):
    erg = []
    for elem in list:
        erg.insert(len(erg),[elem])
    return erg

def injectCountInRowNames(df):
    erg = []
    for name in df.index.values:
        erg.append(name+" ("+str(stats['count'][name])+")")
    return erg

def getStatsDataFrame(df,columnname,combinations,filterType,ergType):
    avgColumns = ['price','release_date','average_playtime','rating','total_playtime','estimated_revenue','owners_low_bound','owners_high_bound']
    series = []
    names = []
    for combination in combinations:
        if(filterType=='equals'):
            filterErg = multipleFilter(df,[
                              lambda row: equalsFilter(row,columnname,combination)
                          ])
        elif(filterType=='or'):
            filterErg = multipleFilter(df,[
                              lambda row: orFilter(row,columnname,combination)
                          ])
        elif(filterType=='and'):
            filterErg = multipleFilter(df,[
                              lambda row: andFilter(row,columnname,combination)
                          ])
        if(ergType=='mean'):  
            ser = filterErg[avgColumns].mean(numeric_only=False)
        elif(ergType=='median'):  
            ser = filterErg.median(numeric_only=True)
        elif(ergType=='sum'):  
            ser = filterErg[avgColumns].sum(numeric_only=True)
        elif(ergType=='var'):  
            ser = filterErg[avgColumns].var(numeric_only=True)
        ser['count'] = filterErg['appid'].count()
        names.insert(len(names)-1,(','.join(combination))+" ("+str(ser['count'])+")")
        series.insert(len(series)-1,ser)

    erg = pd.concat(series, axis=1,keys=names).transpose().fillna(0)
    #rg.index = injectCountInRowNames(erg)
    return erg

#platformStats = getStatsDataFrame(pDF,'platforms',getAllCombinations(['windows','linux','mac']),'equals','mean')

# %%
#ax = platformStats['dataValues'].plot(kind='bar', stacked=False)
#ax.set_ylabel("Number of games")
#ax.set_title("Distribution of games along the different platforms")
#ax

# %%
#col = avgColumns[5]
#ax = platformStats[col].plot(kind='bar', stacked=False)
#ax.set_ylabel("mean_"+col)
#ax

# %% [markdown]
# #simplePlatformStatsSum = getStatsDataFrame(pDF,
#                                         'platforms',
#                                         [['windows'],['linux'],['mac']] ,
#                                         'or',
#                                         'sum'
#                                        )
#
# #simplePlatformStatsMean = getStatsDataFrame(pDF,
#                                         'platforms',
#                                         [['windows'],['linux'],['mac']] ,
#                                         'or',
#                                         'mean'
#                                        )
# #simplePlatformStatsSum

# %%
#col = avgColumns[0]
#ax = simplePlatformStatsMean['dataValues'].plot(kind='bar', stacked=False)
#ax.set_ylabel("Number of games")
#ax.set_title("Distribution of games along the different platforms")
#ax

# %% [markdown]
# preFilteredDF = multipleFilter(pDF,[
#     lambda row: equalsFilter(row,'platforms',['mac']),
#     lambda row: biggerFilter(row,'owners_low_bound',0),
#     lambda row: biggerFilter(row,'price',0),
#     #lambda row: smallerFilter(row,'price',5),
#     lambda row: orFilter(row,'categories',['Single-player']),
#     lambda row: notFilter(row,'categories',['Multi-player']),
# ])
#
# stats = getStatsDataFrame(preFilteredDF,'categories',
#                   [['Single-player'],['Multi-player']],
#                   'or','mean')
#
# ax = stats['total_playtime'].plot(kind='bar', stacked=False)
# ax.set_ylabel('total_playtime')
# ax.set_title("Distribution")
# ax#geht nicht

# %%
preFilteredDF = multipleFilter(pDF,[
    lambda row: biggerFilter(row,'owners_low_bound',10000),
    lambda row: notSameFilter(row,'appid',570),
    lambda row: notSameFilter(row,'appid',578080),
    lambda row: notSameFilter(row,'appid',730),
#    lambda row: notFilter(row,'developer',['Valve']),
#    lambda row: notFilter(row,'publisher',['Valve']),
    
#    lambda row: orFilter(row,'categories',['Single-player']),
#    lambda row: notFilter(row,'categories',['Multi-player']),
])
#570 578080 730

allcat = get_unique_list(pDF['categories'])

stats = getStatsDataFrame(preFilteredDF,'categories',
                  splitList(get_unique_list(pDF['categories'])),
                  'or','mean')
#stats
stats.fillna(pd.Timedelta(seconds=0))
ax = stats['owners_low_bound'].plot(kind='bar', stacked=False)
ax.set_ylabel('owners_low_bound')
#ax.set_xlabel(injectCountInRowNames(stats))
ax.set_title("mean owners_low_bound for each categorie")
stats
#preFilteredDF.sort_values(by='total_playtime',ascending=False)
# Out:
#                                        price                  release_date  \
# Steam Trading Cards (4542)          7.678807 2015-11-29 21:33:12.602377728
# Mods (2)                            0.000000 2009-06-08 12:00:00.000000000
# Steam Turn Notifications (25)       6.889200 2015-11-25 10:33:36.000000000
# Single-player (7856)                7.362584 2015-05-23 22:55:06.720977664
# Valve Anti-Cheat enabled (92)      12.387609 2012-02-13 14:52:10.434782720
# Stats (700)                         6.956900 2015-07-20 23:35:18.857142784
# Multi-player (1979)                 8.860258 2014-11-06 03:29:33.623042048
# Mods (require HL2) (1)              0.000000 2008-10-03 00:00:00.000000000
# Steam Achievements (5027)           8.356344 2015-11-27 23:57:42.502486528
# Online Multi-Player (1014)          8.464724 2017-03-17 14:36:12.781064960
# VR Support (110)                    9.346455 2016-01-28 16:34:54.545454592
# Commentary available (81)           6.167778 2015-04-20 11:51:06.666666752
# Steam Workshop (506)               12.747273 2015-12-02 13:19:41.027667968
# Shared/Split Screen (689)           9.590740 2015-08-18 07:50:14.804063744
# Cross-Platform Multiplayer (568)    6.117289 2015-12-27 07:28:43.943662080
# Online Co-op (513)                  9.631813 2017-03-21 07:48:46.315789568
# Partial Controller Support (1512)   7.995608 2015-05-05 12:11:25.714285824
# Steam Cloud (3075)                 10.094407 2015-08-08 12:02:06.439024384
# MMO (299)                           2.792207 2016-08-12 03:31:54.381270784
# Captions available (287)            8.870000 2015-06-15 14:28:00.836237056
# Local Multi-Player (343)           10.161837 2016-09-20 23:43:12.419825152
# Includes level editor (478)         9.430837 2015-02-14 23:56:59.246862080
# Full controller support (2071)     10.309324 2016-01-03 06:43:58.725253376
# SteamVR Collectibles (27)          17.891111 2017-03-06 15:06:40.000000000
# Local Co-op (246)                  10.302886 2016-10-19 23:54:08.780487680
# Steam Leaderboards (1341)           8.357845 2015-05-24 03:31:32.617449728
# In-App Purchases (502)              3.335797 2017-06-21 11:37:03.107569664
# Co-op (866)                         9.793730 2015-04-16 10:58:28.545034496
# Includes Source SDK (26)            3.426154 2012-01-21 18:27:41.538461440
#
#                                    average_playtime     rating  \
# Steam Trading Cards (4542)                      440  67.700244
# Mods (2)                                        532  82.750696
# Steam Turn Notifications (25)                   212  69.003282
# Single-player (7856)                            405  67.306262
# Valve Anti-Cheat enabled (92)                  1635  76.270432
# Stats (700)                                     540  69.585805
# Multi-player (1979)                             701  66.737500
# Mods (require HL2) (1)                          948  82.135015
# Steam Achievements (5027)                       431  69.828067
# Online Multi-Player (1014)                      692  65.870736
# VR Support (110)                                645  72.494851
# Commentary available (81)                       758  71.114728
# Steam Workshop (506)                            998  75.706232
# Shared/Split Screen (689)                       339  70.363930
# Cross-Platform Multiplayer (568)               1012  67.684411
# Online Co-op (513)                              811  67.576853
# Partial Controller Support (1512)               504  67.258099
# Steam Cloud (3075)                              431  72.861583
# MMO (299)                                      1447  58.567611
# Captions available (287)                        980  73.329222
# Local Multi-Player (343)                        536  70.741794
# Includes level editor (478)                     749  73.628383
# Full controller support (2071)                  368  72.562013
# SteamVR Collectibles (27)                        80  81.690094
# Local Co-op (246)                               360  73.923164
# Steam Leaderboards (1341)                       404  71.648729
# In-App Purchases (502)                          693  59.987938
# Co-op (866)                                     883  68.778904
# Includes Source SDK (26)                       1206  79.838277
#
#                                    total_playtime  estimated_revenue  \
# Steam Trading Cards (4542)              430497038       2.367989e+06
# Mods (2)                                266250000       0.000000e+00
# Steam Turn Notifications (25)            24655200       8.063720e+05
# Single-player (7856)                    281457682       2.077984e+06
# Valve Anti-Cheat enabled (92)          9446427826       2.129025e+07
# Stats (700)                             910081700       2.766722e+06
# Multi-player (1979)                    1078476417       4.125670e+06
# Mods (require HL2) (1)                  474000000       0.000000e+00
# Steam Achievements (5027)               437884030       2.598881e+06
# Online Multi-Player (1014)              869099783       2.566286e+06
# VR Support (110)                       1780199727       3.470153e+06
# Commentary available (81)              2860897530       5.753975e+06
# Steam Workshop (506)                   1951933972       7.497805e+06
# Shared/Split Screen (689)               171906908       2.053810e+06
# Cross-Platform Multiplayer (568)       1301108204       2.938550e+06
# Online Co-op (513)                      978238849       3.608042e+06
# Partial Controller Support (1512)       629866567       2.569488e+06
# Steam Cloud (3075)                      422206930       3.417318e+06
# MMO (299)                              1750400635       1.725359e+06
# Captions available (287)               1765015261       4.946793e+06
# Local Multi-Player (343)                804503148       2.486762e+06
# Includes level editor (478)            1539799079       5.040590e+06
# Full controller support (2071)          340035176       3.660316e+06
# SteamVR Collectibles (27)                10615555       1.355519e+06
# Local Co-op (246)                       283069349       2.639111e+06
# Steam Leaderboards (1341)               204085108       2.303937e+06
# In-App Purchases (502)                 1860133326       1.911771e+06
# Co-op (866)                            1374023810       5.372319e+06
# Includes Source SDK (26)               5644176923       1.838711e+07
#
#                                    owners_low_bound  owners_high_bound  count
# Steam Trading Cards (4542)                   250409             553985   4542
# Mods (2)                                     500000            1000000      2
# Steam Turn Notifications (25)                108400             232000     25
# Single-player (7856)                         203310             447543   7856
# Valve Anti-Cheat enabled (92)               2450978            5302173     92
# Stats (700)                                  371228             824571    700
# Multi-player (1979)                          461793            1004396   1979
# Mods (require HL2) (1)                       500000            1000000      1
# Steam Achievements (5027)                    249100             545573   5027
# Online Multi-Player (1014)                   391272             851429   1014
# VR Support (110)                             463909            1070909    110
# Commentary available (81)                   1121358            2414197     81
# Steam Workshop (506)                         608577            1353853    506
# Shared/Split Screen (689)                    195297             431857    689
# Cross-Platform Multiplayer (568)             404823             886795    568
# Online Co-op (513)                           456413            1003021    513
# Partial Controller Support (1512)            290291             646726   1512
# Steam Cloud (3075)                           266504             585983   3075
# MMO (299)                                    652675            1392809    299
# Captions available (287)                     594773            1291463    287
# Local Multi-Player (343)                     275072             598104    343
# Includes level editor (478)                  559142            1251987    478
# Full controller support (2071)               265668             581265   2071
# SteamVR Collectibles (27)                    107407             233333     27
# Local Co-op (246)                            239186             531707    246
# Steam Leaderboards (1341)                    195667             430686   1341
# In-App Purchases (502)                       630398            1380079    502
# Co-op (866)                                  545958            1196824    866
# Includes Source SDK (26)                    3320000            6767307     26

# %%
preFilteredDF = multipleFilter(pDF,[
    lambda row: biggerFilter(row,'owners_low_bound',10000),
    lambda row: orFilter(row,'categories',['VR Support']),
    
#    lambda row: orFilter(row,'categories',['Single-player']),
#    lambda row: notFilter(row,'categories',['Multi-player']),
])

preFilteredDF.sort_values(by='total_playtime',ascending=False).head(5)


def injectCountInRowNames(df):
    erg = []
    for name in df.index.values:
        erg.insert(len(erg)-1,name+" ("+str(stats['count'][name])+")")
    return erg

injectCountInRowNames(stats)
stats.index.values
# Out:
# array(['Steam Trading Cards', 'Mods', 'Steam Turn Notifications',
#        'Single-player', 'Valve Anti-Cheat enabled', 'Stats',
#        'Multi-player', 'Mods (require HL2)', 'Steam Achievements',
#        'Online Multi-Player', 'VR Support', 'Commentary available',
#        'Steam Workshop', 'Shared/Split Screen',
#        'Cross-Platform Multiplayer', 'Online Co-op',
#        'Partial Controller Support', 'Steam Cloud', 'MMO',
#        'Captions available', 'Local Multi-Player',
#        'Includes level editor', 'Full controller support',
#        'SteamVR Collectibles', 'Local Co-op', 'Steam Leaderboards',
#        'In-App Purchases', 'Co-op', 'Includes Source SDK'], dtype=object)
